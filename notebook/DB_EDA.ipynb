# %%
import pandas as pd
import numpy as np

# %%
file_path = "../dataset/Chicago_Energy_Benchmarking_20260226.csv"
df = pd.read_csv(file_path, low_memory=False)
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.columns
df.describe(include="all")

# %%
missing = df.isnull().sum().sort_values(ascending=False)
missing

# %%
df["ENERGY STAR Score"].describe()

# %%
df["Site EUI (kBtu/sq ft)"].describe()

# %%
df["Total GHG Emissions (Metric Tons CO2e)"].describe()

# %%
df.dtypes
